# %%
import cv2

# %%
Image = cv2.imread('cat.JPG')
if image is None: 
    print("خطأ:لم يتم العثور على الصورة ,تاكد من المسار ")

# %%
height, width, channels = image.shape
print(f"الارتفاع (Height):{height}")
print(f"العرض  (Width):{width}")
print(f"عدد القنوات (Channels):{channels}")
# Out:
# الارتفاع (Height):460
# العرض  (Width):736
# عدد القنوات (Channels):3

# %%
cv2.imshow('Original Image ',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('cat.JPG_converted.png',image)
print("بنجاح png تم حفظ نسخة ")
# Out:
# بنجاح png تم حفظ نسخة

# %%
from IPython.display import Image,display 
display(Image("cat.JPG"))
